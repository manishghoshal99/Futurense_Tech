# %%
import pandas as pd
import plotly.express as px

# Load the dataset
data = pd.read_csv('/Users/manishghoshal/Downloads/Futurense_Internship-main/Final Internship Capstone Project/Financial Analytics/financialanalytics.csv')

# %%
# Create a scatter plot of EPS vs. P/E ratio
fig = px.scatter(data, x='EarningsPerShare', y='PriceEarningsRatio', color='Industry', hover_name='Company',
                 title='Earnings per Share vs. Price-Earnings Ratio')
fig.update_layout(xaxis_title='Earnings per Share (EPS)', yaxis_title='Price-Earnings Ratio (P/E)')
fig.show()

# %%
# Calculate the correlation between EPS and P/E ratio
eps_pe_corr = data['EarningsPerShare'].corr(data['PriceEarningsRatio'])
print(f"Correlation between Earnings per Share and Price-Earnings Ratio: {eps_pe_corr:.2f}")
# Out:
# Correlation between Earnings per Share and Price-Earnings Ratio: -0.03

# %%
# Identify companies with high EPS and low P/E ratio
high_eps_low_pe = data[(data['EarningsPerShare'] > data['EarningsPerShare'].quantile(0.75)) & (data['PriceEarningsRatio'] < data['PriceEarningsRatio'].quantile(0.25))]
print("Companies with high EPS and low P/E ratio:")
print(high_eps_low_pe[['Company', 'EarningsPerShare', 'PriceEarningsRatio']])
# Out:
# Companies with high EPS and low P/E ratio:
#     Company  EarningsPerShare  PriceEarningsRatio
# 16        A          9.353192            9.574896
# 28        D          6.047537           13.504846
# 29        C          9.024287            5.929311
# 52        B          7.436626            9.370003
# 58        A          6.942359           13.171558
# ..      ...               ...                 ...
# 910       B          8.365708            9.238152
# 929       A          6.159077           13.252186
# 932       A          6.151172            8.385302
# 975       B          8.780236           12.014596
# 995       A          5.662961           13.847361
#
# [65 rows x 3 columns]

# %%
# Investigate potential reasons for high EPS and low P/E ratio
for company in high_eps_low_pe['Company']:
    company_data = data[data['Company'] == company]
    print(f"\nCompany: {company}")
    print(f"Revenue: {company_data['Revenue'].values[0]}")
    print(f"Profit: {company_data['Profit'].values[0]}")
    print(f"Market Capitalization: {company_data['MarketCap'].values[0]}")
    print("Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.")
# Out:
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: D
# Revenue: 522120
# Profit: 98862
# Market Capitalization: 81732093
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: C
# Revenue: 304927
# Profit: 49963
# Market Capitalization: 88554112
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: B
# Revenue: 959342
# Profit: 32131
# Market Capitalization: 31326134
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.
#
# Company: A
# Revenue: 897681
# Profit: -4866
# Market Capitalization: 20679648
# Potential reasons could be undervalued stock, high growth potential, or industry-specific factors.

# %% [markdown]
# **Infer findings:**
#
# 1. **Relationship between EPS and P/E Ratio:**
#    - The scatter plot shows the distribution of EPS and P/E ratio for each company.
#    - Analyzing this can reveal any patterns or trends in the relationship between EPS and P/E ratio.
#
# 2. **Correlation between EPS and P/E Ratio:**
#    - The correlation coefficient indicates the strength and direction of the relationship between EPS and P/E ratio.
#
# 3. **Companies with High EPS but Low P/E Ratio:**
#    - Companies with high EPS but low P/E ratio may have strong earnings growth potential or undervalued stocks.
#    - Reasons for low P/E ratios could include market sentiment, industry trends, or financial performance.
